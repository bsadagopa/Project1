# %% [markdown]
# # Todays News Trends
#
# ### Program gets the current to headlines from
# *All News Media*
# ### and performs sentiment analysis on the news to identify the current sentiment.

# %%
# Dependencies
import string
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time
import math

import requests

from pprint import pprint

import seaborn as sns

# %matplotlib inline

# News API
import newsapi
from newsapi.newsapi_client import NewsApiClient
from newsapi.articles import Articles
from newsapi.sources import Sources

# NLTK
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import FreqDist

#word cloud
from wordcloud import WordCloud

# %%
# Twitter API Keys
from config import (consumer_key, consumer_secret, access_token, access_token_secret)
#News API Keys
from config import newapi_key

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

#from config import (consumer_key, consumer_secret,
#                    access_token, access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Init
newsapi = NewsApiClient(api_key='4b7e7bb7670e40f788f92667a6a2dd64')
newsapi_Articles = Articles(API_KEY=newapi_key)
newsapi_Sources = Sources(API_KEY=newapi_key)

# %% [markdown]
# ### Method: getCurrentHeadlines()
# ### Get the top headlines from newsapi.
# Default value country=US, lanuage=english, page_size=100 (max allowed) <br/>
# Other paramers like q (query), sources, categories and pages can be passed in.
#
# ##### Note: country and category params cannot be used with sources param
# *Category possible values:* 'business','entertainment','general','health','science','sports','technology'
#
# **Returns a Dictionary** <br/>
# Dictionary["totalResults"] key will provide the total number of articles that were returned by newsapi. <br/>
# The method returns only Max of 500 articles <br/>

# %%
def getCurrentHeadlines(q=None, 
                        sources=None, 
                        language='en', 
                        country='us', 
                        category=None, 
                        page_size=100, 
                        page=None):
    if(sources != None):
        country = None
        category = None
        
    print(f"Calling => getCurrentHeadlines(q={q}, \n\
                                sources={sources},\n\
                                language={language},\n\
                                country={country},\n\
                                category={category},\n\
                                page_size={page_size},\n\
                                page={page})")

    results = newsapi.get_top_headlines(q, 
                                              sources, 
                                              language, 
                                              country, 
                                              category, 
                                              page_size, 
                                              page)
    results_count = results['totalResults'] 
    # return value
    top_headlines = results['articles']
    
    # the first 100 has already been pulled in the first call, 
    # so start pulling from page 2
    loopcount = int(results_count / 100)
    page = 2
    
    while(loopcount > 0):
        #print('INSIDE LOOP')
        #print(f"output list size = {len(top_headlines)}")
        
        results = None
        results = newsapi.get_top_headlines(q, 
                                          sources, 
                                          language, 
                                          country, 
                                          category, 
                                          page_size, 
                                          page)
        #print(f"page {page} pulled {results['totalResults']}")
        #print(f"loopcount {loopcount} pulled {len(results['articles'])}")
        
        top_headlines = top_headlines + results['articles']
        page += 1
        loopcount -= 1
        
        # break at 500 articles
        if(page > 5):
            break
         
    print(f"totalResults from newsapi.get_top_headlines() = {results_count} \n \
          top_headlines returned by the method = {len(top_headlines)}")
    return top_headlines

# %% [markdown]
# **Call Details**
#
# *Default value country=US, lanuage=english, page_size=100
# Other paramers like q (query), sources, categories and pages can be passed in.*
#
# ##### Note: country and category params cannot be used with sources param
# Category possible values: 'business','entertainment','general','health','science','sports','technology'
#
# *Sample:*
#
# **Correct Call:**
#
# getCurrentHeadlines() *returns top headlines for US, English* <br/>
# getCurrentHeadlines(sources='bbc-news') *returns top headlines from bbc-news, English*<br/>
# getCurrentHeadlines(category='sports') *returns top headlines for sports, in English (not restricted to US)* <br/>
# getCurrentHeadlines(q='FIFA World Cup', country=None) *returns top headlines for sports, in English (not restricted to US)* <br/>
#
# **Incorrect Call: Category will be made None because sources is set.**
#
# getCurrentHeadlines(sources='bbc-news', *'category='sports'*)
#
# **Returns a Dictionary** <br/>
# Dictionary["totalResults"] key will provide the total number of articles that were returned by newsapi. <br/>
# The method returns only Max of 500 articles <br/>

# %%
news_sources = 'google-news,abc-news,cbs-news,cnbc,bbc-news,cnn,fox-news, \
                nbc-news,the-washington-post,the-washington-times'
#headlines = getCurrentHeadlines(sources=news_sources)
#headlines = getCurrentHeadlines(country=None)
#headlines = getCurrentHeadlines()

# %% [markdown]
# ## Get top World wide Headlines

# %%
world_headlines = getCurrentHeadlines(country=None)
world_headlines_df = pd.DataFrame(world_headlines)
world_headlines_df['News Channel'] = [article['source']['name'] for article in world_headlines]
world_headlines_df.head(2)
# Out:
# Calling => getCurrentHeadlines(q=None,
#                                 sources=None,
#                                 language=en,
#                                 country=None,
#                                 category=None,
#                                 page_size=100,
#                                 page=None)
# totalResults from newsapi.get_top_headlines() = 856
#            top_headlines returned by the method = 500
#          author                                        description  \
# 0  Nasir Jabbar  Ali explains how football saved him from going...
# 1     Amy Spiro  Universal sends warning letter to composer of ...
#
#             publishedAt                                             source  \
# 0  2018-07-07T11:00:00Z  {'id': 'the-sport-bible', 'name': 'The Sport B...
# 1  2018-07-03T21:28:00Z  {'id': 'the-jerusalem-post', 'name': 'The Jeru...
#
#                                                title  \
# 0  From Gangs To Goals: How Football Saved Englan...
# 1         Does 'Toy' sound like 'Seven Nation Army'?
#
#                                                  url  \
# 0  http://www.thesportbible.com/football/news-fro...
# 1  https://www.jpost.com/OMG/Does-Toy-sound-like-...
#
#                                           urlToImage        News Channel
# 0  http://beta.ems.ladbiblegroup.com/s3/content/8...     The Sport Bible
# 1  https://images.jpost.com/image/upload/f_auto,f...  The Jerusalem Post

# %% [markdown]
# ## Get top US Headlines

# %%
us_headlines = getCurrentHeadlines()
us_headlines_df = pd.DataFrame(us_headlines)
us_headlines_df['News Channel'] = [article['source']['name'] for article in us_headlines]
us_headlines_df.head(2)
# Out:
# Calling => getCurrentHeadlines(q=None,
#                                 sources=None,
#                                 language=en,
#                                 country=us,
#                                 category=None,
#                                 page_size=100,
#                                 page=None)
# totalResults from newsapi.get_top_headlines() = 20
#            top_headlines returned by the method = 20
#           author                                        description  \
# 0     John Bacon  Rescuers in Thailand were racing against time ...
# 1  David Jackson  President Donald Trump complains about defense...
#
#             publishedAt                                    source  \
# 0  2018-07-03T18:20:07Z  {'id': 'usa-today', 'name': 'USA Today'}
# 1  2018-07-03T18:06:00Z  {'id': 'usa-today', 'name': 'USA Today'}
#
#                                                title  \
# 0  Thailand cave rescue: Boys may have to scuba t...
# 1  Donald Trump tells NATO allies to pay more for...
#
#                                                  url  \
# 0  https://www.usatoday.com/story/news/world/2018...
# 1  https://www.usatoday.com/story/news/politics/2...
#
#                                           urlToImage News Channel
# 0  https://www.gannett-cdn.com/-mm-/6ad70e37d9db5...    USA Today
# 1  https://www.gannett-cdn.com/-mm-/f8cdc1247de94...    USA Today

# %% [markdown]
# ## Word Count

# %% [markdown]
# ### sentence preprocessing into cleaned strings

# %%
def preprocessing(text):
    words = word_tokenize(text)
    tokens = [w for w in words if w.lower() not in string.punctuation]
    stopw = stopwords.words('english')
    stopw = stopw + ["n't",'',"the"]
    tokens = [token for token in tokens if token not in stopw]
    # remove words less than three letters
    tokens = [word for word in tokens if len(word)>=3]
    #lower capitalization
    tokens = [word.lower() for word in tokens]
    # lemmatize
    lemma = WordNetLemmatizer()
    tokens = [lemma.lemmatize(word) for word in tokens]
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

# %%
def generteWordCloud(text_as_strings, plot_title="Top Headline Words"):

    wordcloud = WordCloud().generate(text_as_strings)
    
    #Print the word cloud
    plt.figure(figsize=(12,12))
    plt.imshow(wordcloud.recolor(random_state=2017))
    plt.title(plot_title)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Top Words from World Headlines

# %%
def generateCleanWordsFromTitles(titles):
    cleaned_words = ''

    for title in titles:
        cleaned_words = cleaned_words + ' ' + preprocessing(title)
    
    return cleaned_words

# %%
generteWordCloud(generateCleanWordsFromTitles(world_headlines_df['title']), "World Headlines - Top Words")

# %% [markdown]
# ## Top Words from US Headlines

# %%
generteWordCloud(generateCleanWordsFromTitles(us_headlines_df['title']), "US Headlines - Top Words")

# %% [markdown]
# ## Find the top 10 words in the world media today
# ## Generate word frequency

# %% [markdown]
# ## Find the top 10 words in the US media today
# ## Generate word frequency

# %%
def generateWordFrequency(text_as_strings):
    #print(text_as_strings)
    tokens = text_as_strings.split(" ")
    
    freq = {}

    for i in tokens:
        
        if i in freq:
            freq[i] += 1
        else:
            freq[i] = 1
    
    return freq
    
#print(freq)

# %%
#generateCleanWordsFromTitles(world_headlines_df['title'])

# %%
#generateWordFrequency(world_headline_words)
w_wf = generateWordFrequency(generateCleanWordsFromTitles(world_headlines_df['title']))

# %%
#type(wf)

# %%
FreqDist.most_common(wf)[:20]
# Out:
# [('trump', 50),
#  ('the', 40),
#  ('world', 25),
#  ('cup', 24),
#  ('england', 23),
#  ('2018', 20),
#  ('live', 20),
#  ('day', 18),
#  ('court', 18),
#  ('say', 16),
#  ('colombia', 15),
#  ('new', 15),
#  ('cave', 15),
#  ('video', 13),
#  ('may', 13),
#  ('thai', 13),
#  ('supreme', 13),
#  ('what', 12),
#  ('report', 11),
#  ('time', 11)]

# %%
us_wf = generateWordFrequency(generateCleanWordsFromTitles(us_headlines_df['title']))

# %%
FreqDist.most_common(us_wf)[:20]
# Out:
# [('trump', 6),
#  ('thailand', 2),
#  ('cave', 2),
#  ('rescue', 2),
#  ('nato', 2),
#  ('fired', 2),
#  ('order', 2),
#  ('', 1),
#  ('boy', 1),
#  ('may', 1),
#  ('scuba', 1),
#  ('safety', 1),
#  ('even', 1),
#  ('swim', 1),
#  ('donald', 1),
#  ('tell', 1),
#  ('ally', 1),
#  ('pay', 1),
#  ('defense', 1),
#  ('raising', 1)]

# %% [markdown]
# ## Getting Sentiment Analysis for Headlines
# **Sentiment Analysis** <br/>
# *Using vaderSentiment Analyzer to analize the new media sentiment from the headline*

# %% [markdown]
# ### getSentiments Method
# ### Input: Dataframe returned by getCurrentHeadlines() call
# ### Return: sentiment list
# #### Sentiment parameters
#     "Headlines",
#     "Channel",
#     "Compound",
#     "Positive",
#     "Negative",
#     "Neutral"

# %%
def getSentiments(df):
    sentiments = []

    for index, row in df.iterrows():

        words = preprocessing(row['title'])

        # Run Vader Analysis on each headline
        results = analyzer.polarity_scores(words)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        # Add sentiments for each tweet into a list
        sentiments.append({"Headlines": row['title'], 
                           "Channel": row['News Channel'],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg})
        
    return sentiments

# %% [markdown]
# ## Sentiment Analysis from World Headlines

# %%
world_sentiment_df = pd.DataFrame(getSentiments(world_headlines_df))

# %%
world_sentiment_df
# Out:
#                          Channel  Compound  \
# 0                The Sport Bible    0.4215
# 1             The Jerusalem Post    0.3612
# 2             The Jerusalem Post   -0.8625
# 3             The Jerusalem Post    0.2500
# 4             The Jerusalem Post    0.0000
# 5             The Jerusalem Post   -0.1027
# 6             The Jerusalem Post   -0.7430
# 7             The Jerusalem Post   -0.6597
# 8                       Buzzfeed   -0.7906
# 9                     Daily Mail    0.4767
# 10            The New York Times    0.5574
# 11                     The Hindu    0.4939
# 12                     The Hindu    0.3818
# 13           National Geographic    0.0000
# 14           National Geographic    0.0000
# 15           National Geographic    0.0000
# 16           National Geographic    0.0000
# 17           National Geographic   -0.5574
# 18           National Geographic   -0.1655
# 19           National Geographic    0.0000
# 20           National Geographic    0.0000
# 21                           IGN    0.0000
# 22           National Geographic    0.2732
# 23           National Geographic   -0.5994
# 24              Associated Press    0.0000
# 25                       Fortune    0.0000
# 26                          CNBC   -0.7783
# 27                      NBC News   -0.5267
# 28             The Guardian (UK)   -0.3612
# 29                      Buzzfeed    0.0000
# ..                           ...       ...
# 470                The Lad Bible    0.0000
# 471                      Polygon    0.0000
# 472  Australian Financial Review    0.0000
# 473  Australian Financial Review    0.0000
# 474  Australian Financial Review   -0.6908
# 475  Australian Financial Review    0.0000
# 476  Australian Financial Review    0.0000
# 477                        Wired    0.3804
# 478                        Wired    0.0000
# 479                        Wired   -0.6597
# 480              National Review    0.0000
# 481                 Ars Technica    0.1779
# 482                The Telegraph    0.0258
# 483                    USA Today    0.3612
# 484              Bleacher Report   -0.4717
# 485           Al Jazeera English   -0.8074
# 486                        MSNBC    0.0000
# 487         The Washington Times    0.4939
# 488                         Time   -0.9062
# 489               Financial Post    0.5994
# 490         The Washington Times   -0.2732
# 491                      Polygon   -0.0772
# 492                    The Verge    0.4588
# 493                          RTE    0.0000
# 494                Reddit /r/all    0.0000
# 495                          CNN    0.5106
# 496                         CNBC   -0.1531
# 497    The American Conservative    0.0000
# 498                    Vice News    0.1280
# 499                        MSNBC   -0.5994
#
#                                              Headlines  Negative  Neutral  \
# 0    From Gangs To Goals: How Football Saved Englan...     0.763    0.000
# 1           Does 'Toy' sound like 'Seven Nation Army'?     0.706    0.000
# 2    Israel declares war on PA funding for terroris...     0.411    0.589
# 3    Report: Shin Bet restores security for Barak a...     0.455    0.197
# 4    PM at Protective Edge memorial: ‘There is no  ...     1.000    0.000
# 5     PA warns against holding Eurovision in Jerusalem     0.682    0.318
# 6         Israel gets Twitter to block terror accounts     0.388    0.612
# 7    Mother of lost soldier to 'Post': We hear only...     0.526    0.474
# 8    Twitter Is At War Over The Correct Way To Pron...     0.588    0.412
# 9    British diver's mother reveals how proud late ...     0.693    0.000
# 10   In Los Angeles, Where the Rich and the Destitu...     0.625    0.000
# 11   A good beginning: on the Cauvery Water Managem...     0.488    0.000
# 12   Jalalabad gauntlet: on the growth of IS in Afg...     0.536    0.000
# 13   Koalas Eat Toxic Leaves to Survive—Now Scienti...     1.000    0.000
# 14                         Looking for the Mother Road     1.000    0.000
# 15   In This City, Students Take Over on the Last D...     1.000    0.000
# 16                 Horses Had Dentists 3,000 Years Ago     1.000    0.000
# 17   What A Newborn Sun Bear Teaches Us About the I...     0.690    0.310
# 18   She Fought for a Shark Sanctuary. But Does It ...     0.784    0.216
# 19     Why You Can’t Write Messages With Fireworks—Yet     1.000    0.000
# 20           19 Photos of Animals Living the High Life     1.000    0.000
# 21   Pokemon Quest Evolution List - Pokemon Quest W...     1.000    0.000
# 22    25 Beautiful Places That Are off the Beaten Path     0.374    0.262
# 23   Rare Video Shows Death Match Between Camel Spi...     0.672    0.328
# 24   Trump to rescind Obama-era guidance on affirma...     1.000    0.000
# 25   Diet Coke Just Dropped Its Lime Flavor. Cherry...     1.000    0.000
# 26   Paul Ryan spokesman on report Jim Jordan alleg...     0.606    0.394
# 27   Prosecutors debunk Trump-fueled conspiracy the...     0.702    0.298
# 28   Hammond to warn cabinet of risks of Canada-sty...     0.588    0.412
# 29   Watch: Women Test Themselves For Food Sensitiv...     1.000    0.000
# ..                                                 ...       ...      ...
# 470  Gareth Southgate Could Take A Page Out Of Loui...     1.000    0.000
# 471  Mutant Football League comes to Nintendo Switc...     1.000    0.000
# 472     Google's man in Oz gets a 'real job' at Domain     1.000    0.000
# 473  Coal veteran Tony Haggarty blasts green groups...     1.000    0.000
# 474   Deloitte 'covered up' attempted rape allegations     0.460    0.540
# 475           Penfolds goes from Grange to rocket fuel     1.000    0.000
# 476        Coalition fiddles as renewables remake grid     1.000    0.000
# 477  Do Thundershirts Really Calm Dogs During Firew...     0.659    0.000
# 478  10 Scathing Political Satires to Stream This I...     1.000    0.000
# 479  The Bitter Battle to Turn an Old Factory Into ...     0.597    0.403
# 480                       Against the Trump Trade Bill     1.000    0.000
# 481  Dealmaster: Amazon Prime Day returns on July 1...     0.841    0.000
# 482  VIP paedophile accuser 'Nick' charged with per...     0.219    0.415
# 483  Sex trafficking survivor says he was sold duri...     0.706    0.000
# 484  Lakers May Not Win a Title in 2019, but That's...     0.765    0.235
# 485  Egypt's Sinai, war on terror, and the 'deal of...     0.354    0.646
# 486  Examining the consequences of fracking in Trum...     1.000    0.000
# 487  National Education Association gives Colin Kae...     0.686    0.000
# 488  President Trump Continues Attacking Maxine Wat...     0.423    0.577
# 489  Terence Corcoran: How smug politicians — inclu...     0.604    0.000
# 490  Trump administration pushes colleges to drop r...     0.769    0.231
# 491  Generation Zero will build on stealth mechanic...     0.860    0.140
# 492    Polk Command Bar review: smarter than it sounds     0.625    0.000
# 493  Woman and son sue over access to 'adoption' re...     1.000    0.000
# 494   I don't think the system works. • r/PrequelMemes     1.000    0.000
# 495                       Live: Thai cave rescue - CNN     0.548    0.000
# 496  Wall Street is not impressed by Tesla's Model ...     0.541    0.250
# 497  The Absurdity of Seeking Iran’s ‘Unconditional...     1.000    0.000
# 498  Trump is using U.S. troops as a bargaining chi...     0.857    0.000
# 499  Trump tweets: If not for me, we'd be at war wi...     0.506    0.494
#
#      Positive
# 0       0.237
# 1       0.294
# 2       0.000
# 3       0.348
# 4       0.000
# 5       0.000
# 6       0.000
# 7       0.000
# 8       0.000
# 9       0.307
# 10      0.375
# 11      0.512
# 12      0.464
# 13      0.000
# 14      0.000
# 15      0.000
# 16      0.000
# 17      0.000
# 18      0.000
# 19      0.000
# 20      0.000
# 21      0.000
# 22      0.364
# 23      0.000
# 24      0.000
# 25      0.000
# 26      0.000
# 27      0.000
# 28      0.000
# 29      0.000
# ..        ...
# 470     0.000
# 471     0.000
# 472     0.000
# 473     0.000
# 474     0.000
# 475     0.000
# 476     0.000
# 477     0.341
# 478     0.000
# 479     0.000
# 480     0.000
# 481     0.159
# 482     0.366
# 483     0.294
# 484     0.000
# 485     0.000
# 486     0.000
# 487     0.314
# 488     0.000
# 489     0.396
# 490     0.000
# 491     0.000
# 492     0.375
# 493     0.000
# 494     0.000
# 495     0.452
# 496     0.209
# 497     0.000
# 498     0.143
# 499     0.000
#
# [500 rows x 6 columns]

# %%
world_sentiment_heatmap = world_sentiment_df.pivot_table(values='Compound',index='Headlines',columns='Channel')
sns.heatmap(world_sentiment_heatmap)

# %% [markdown]
# ## Sentiment Analysis from US Headlines

# %%
us_sentiment_df = pd.DataFrame(getSentiments(us_headlines_df))
us_sentiment_df
# Out:
#                 Channel  Compound  \
# 0             USA Today    0.7269
# 1             USA Today   -0.2960
# 2      Business Insider   -0.7003
# 3              Fox News   -0.6249
# 4       Nydailynews.com    0.0000
# 5              Politico   -0.8442
# 6              NBC News   -0.2500
# 7          Cbslocal.com   -0.3400
# 8   The Washington Post    0.4767
# 9   The Washington Post   -0.7845
# 10             Fox News   -0.6705
# 11  The Washington Post    0.0000
# 12                  CNN    0.0000
# 13              Npr.org    0.0000
# 14                 CNBC   -0.1531
# 15   The New York Times   -0.3400
# 16  The Washington Post    0.2732
# 17  The Washington Post    0.3182
# 18                  CNN    0.5106
# 19  The Washington Post   -0.7579
#
#                                             Headlines  Negative  Neutral  \
# 0   Thailand cave rescue: Boys may have to scuba t...     0.534    0.000
# 1   Donald Trump tells NATO allies to pay more for...     0.606    0.280
# 2   There's one glaring problem with Trump's newes...     0.508    0.492
# 3   Walmart boycott campaign launched after outcry...     0.360    0.505
# 4   Gunman surrenders after shooting two construct...     1.000    0.000
# 5   POLITICO Playbook Power Briefing: Jim Jordan a...     0.547    0.453
# 6   Indianapolis church 'detains' Jesus, Mary and ...     0.818    0.182
# 7               Spring Fire Causes Massive 911 Outage     0.676    0.324
# 8   Alan Dershowitz says 'friends on Martha's Vine...     0.721    0.000
# 9   Ex-congressional IT staffer reaches plea deal ...     0.497    0.435
# 10  Gas station manager fired after telling mom, w...     0.476    0.381
# 11  Trump administration moves to rescind Obama-er...     1.000    0.000
# 12  Judge orders Trump admin to consider releasing...     1.000    0.000
# 13                           Bear. Hot Tub. Margarita     1.000    0.000
# 14  Wall Street is not impressed by Tesla's Model ...     0.541    0.250
# 15     New York Times Reassigns Reporter in Leak Case     0.714    0.286
# 16  Trump orders flags flown at half-staff to hono...     0.569    0.171
# 17          Scott Pruitt's perfectly Trumpian scandal     0.297    0.287
# 18  5 things for July 3: NATO, Thailand cave rescu...     0.708    0.000
# 19  As mob lynchings fueled by WhatsApp messages s...     0.468    0.456
#
#     Positive
# 0      0.466
# 1      0.114
# 2      0.000
# 3      0.135
# 4      0.000
# 5      0.000
# 6      0.000
# 7      0.000
# 8      0.279
# 9      0.068
# 10     0.143
# 11     0.000
# 12     0.000
# 13     0.000
# 14     0.209
# 15     0.000
# 16     0.260
# 17     0.416
# 18     0.292
# 19     0.076

# %%
us_sentiment_heatmap = us_sentiment_df.pivot_table(values='Compound',index='Headlines',columns='Channel')
sns.heatmap(us_sentiment_heatmap)
